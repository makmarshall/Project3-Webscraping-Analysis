# %% [markdown]
# # Project 3: Webscraping Data Analysis
# ## Makayla Marshall
# ## 4/11/2023

# %%
# graphing imports
from matplotlib import pyplot as plt
import seaborn as sns

# dataframe imports
import pandas as pd

# %% [markdown]
# ## Read in the webscraped datafiles

# %%
def read_in_csv(csv):
    datafile = csv
    return pd.read_csv(datafile)

# %%
Worldwide2023 = read_in_csv('Worldwide2023.csv')
DomesticDaily2023 = read_in_csv('DomesticDaily2023.csv')
DomesticWeekly2023 = read_in_csv('DomesticWeekly2023.csv')
DomesticMonthly2023 = read_in_csv('DomesticMonthly2023.csv')
DomesticYearly = read_in_csv('DomesticYearly.csv')

# %%
# replace the whole dataframe with integers for the money instead.
def int_for_df(dataframe, col):
    for i in range(0, len(dataframe)):
        c = dataframe[col][i]
        c = c.lstrip('$')
        c = c.replace(',', '')
        c = int(c)
        dataframe[col][i] = c
    return dataframe

# %% [markdown]
# ## Analysis

# %%
sns.set_context('paper')

# %%
Worldwide2023
# Out:
#      Unnamed: 0                                    movie international-profit  \
# 0             0              The Super Mario Bros. Movie            725776389
# 1             1        Ant-Man and the Wasp: Quantumania            474402922
# 2             2                     John Wick: Chapter 4            352730254
# 3             3                                Creed III            271650498
# 4             4                                Scream VI            167443772
# ..          ...                                      ...                  ...
# 195         195                   Il ritorno di Casanova               756271
# 196         196                             Taximetristi               741181
# 197         197                                    Munch               739789
# 198         198                              Eskortnitsa               697982
# 199         199  Metallica: 72 Seasons - Global Premiere               694634
#
# ...

# %%
int_for_df(Worldwide, 'international-profit')
int_for_df(Worldwide2023, 'domestic-profit')
int_for_df(Worldwide2023, 'foreign-profit')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12432\1959393045.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col][i] = c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12432\1449863898.py in <module>
#       1 #int_for_df(Worldwide, 'international-profit')
#       2 #int_for_df(Worldwide2023, 'domestic-profit')
# ----> 3 int_for_df(Worldwide2023, 'foreign-profit')
#
# ~\AppData\Local\Temp\ipykernel_12432\1959393045.py in int_for_df(dataframe, col)
#       5         c = c.lstrip('$')
#       6         c = c.replace(',', '')
# ----> 7         c = int(c)
#       8         dataframe[col][i] = c
#       9     return dataframe
#
# ...

# %%
sns.lineplot(data=Worldwide2023.head(6), x='foreign-profit', y='domestic-profit').set(title='', xlabel='Foreign Profit', ylabel='Domestic Profit')
# Out:
# [Text(0.5, 1.0, ''),
#  Text(0.5, 0, 'Foreign Profit'),
#  Text(0, 0.5, 'Domestic Profit')]

# %%
sns.lineplot(data=Worldwide2023.head(6), y='international-profit', x='domestic-profit').set(ylabel='International Profit', xlabel='Domestic Profit')
# Out:
# [Text(0, 0.5, 'International Profit'), Text(0.5, 0, 'Domestic Profit')]

# %%
sns.lineplot(data=Worldwide2023.head(6), x='foreign-profit', y='international-profit').set(xlabel='Foreign Profit', ylabel='International Profit')
# Out:
# [Text(0.5, 0, 'Foreign Profit'), Text(0, 0.5, 'International Profit')]

# %%
DomesticDaily2023
# Out:
#      Unnamed: 0                        movie                 date        gross
# 0             0  The Super Mario Bros. Movie               Apr 20   $8,275,473
# 1             1  The Super Mario Bros. Movie               Apr 19   $8,691,170
# 2             2  The Super Mario Bros. Movie               Apr 18  $12,881,098
# 3             3  The Super Mario Bros. Movie               Apr 17  $10,007,931
# 4             4  The Super Mario Bros. Movie               Apr 16  $44,105,734
# ..          ...                          ...                  ...          ...
# 105         105     Avatar: The Way of Water                Jan 5  $10,864,987
# 106         106     Avatar: The Way of Water                Jan 4  $12,131,291
# 107         107     Avatar: The Way of Water                Jan 3  $16,965,068
# 108         108     Avatar: The Way of Water                Jan 2  $32,548,656
# 109         109     Avatar: The Way of Water  Jan 1New Year's Day  $36,210,982
#
# [110 rows x 4 columns]

# %%
int_for_df(DomesticDaily2023, 'gross')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12432\1959393045.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col][i] = c
#      Unnamed: 0                        movie                 date     gross
# 0             0  The Super Mario Bros. Movie               Apr 20   8275473
# 1             1  The Super Mario Bros. Movie               Apr 19   8691170
# 2             2  The Super Mario Bros. Movie               Apr 18  12881098
# 3             3  The Super Mario Bros. Movie               Apr 17  10007931
# 4             4  The Super Mario Bros. Movie               Apr 16  44105734
# ..          ...                          ...                  ...       ...
# 105         105     Avatar: The Way of Water                Jan 5  10864987
# ...

# %%
sns.barplot(data=DomesticDaily2023.head(30), y='movie', x='gross').set(title='#1 Movies of the past 30 days - The Super Mario Bros Movie is doing really well.', xlabel='Profit earned that day')
# Out:
# [Text(0.5, 1.0, '#1 Movies of the past 30 days - The Super Mario Bros Movie is doing really well.'),
#  Text(0.5, 0, 'Profit earned that day')]

# %%
sns.lineplot(data=DomesticDaily2023.head(20), x='movie', y='gross').set(title='The last 20 days of top movies', ylabel='Profit earned that day')
# Out:
# [Text(0.5, 1.0, 'The last 20 days of top movies'),
#  Text(0, 0.5, 'Profit earned that day')]

# %%
DomesticWeekly2023
# Out:
#     Unnamed: 0                              movie          date         gross
# 0            0        The Super Mario Bros. Movie     Apr 14-20  $182,489,593
# 1            1        The Super Mario Bros. Movie      Apr 7-13  $278,248,717
# 2            2        The Super Mario Bros. Movie  Mar 31-Apr 6  $183,428,574
# 3            3               John Wick: Chapter 4     Mar 24-30  $147,063,085
# 4            4           Shazam! Fury of the Gods     Mar 17-23  $113,230,818
# 5            5                          Scream VI     Mar 10-16  $157,731,672
# 6            6                          Creed III       Mar 3-9  $144,237,883
# 7            7  Ant-Man and the Wasp: Quantumania  Feb 24-Mar 2  $114,530,891
# 8            8  Ant-Man and the Wasp: Quantumania     Feb 17-23  $183,771,488
# 9            9            Magic Mike's Last Dance     Feb 10-16   $73,245,180
# 10          10                       80 for Brady       Feb 3-9   $89,952,549
# ...

# %%
int_for_df(DomesticWeekly2023, 'gross')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12432\1959393045.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe[col][i] = c
#     Unnamed: 0                              movie          date      gross
# 0            0        The Super Mario Bros. Movie     Apr 14-20  182489593
# 1            1        The Super Mario Bros. Movie      Apr 7-13  278248717
# 2            2        The Super Mario Bros. Movie  Mar 31-Apr 6  183428574
# 3            3               John Wick: Chapter 4     Mar 24-30  147063085
# 4            4           Shazam! Fury of the Gods     Mar 17-23  113230818
# 5            5                          Scream VI     Mar 10-16  157731672
# 6            6                          Creed III       Mar 3-9  144237883
# ...

# %%
sns.barplot(data=DomesticWeekly2023.head(20), y='movie', x='gross').set(title='The last 20 weeks of top movies profits', xlabel='Profit earned that week')
# Out:
# [Text(0.5, 1.0, 'The last 20 weeks of top movies profits'),
#  Text(0.5, 0, 'Profit earned that week')]

# %%
DomesticMonthly2023
# Out:
#    Unnamed: 0                              movie      date         gross
# 0           0                                  -    August             -
# 1           1                                  -       May             -
# 2           2        The Super Mario Bros. Movie     April  $637,528,578
# 3           3                          Creed III     March  $638,150,657
# 4           4  Ant-Man and the Wasp: Quantumania  February  $499,389,940
# 5           5           Avatar: The Way of Water   January  $584,765,684

# %%
sns.lineplot(data=DomesticMonthly2023.head(5), x='movie', y='gross').set(title='The last 5 months of top movies profits', ylabel='Profit earned that month')
# Out:
# [Text(0.5, 1.0, 'The last 5 months of top movies profits'),
#  Text(0, 0.5, 'Profit earned that month')]

# %%
DomesticYearly
# Out:
#     Unnamed: 0                                        #1 movie  year  \
# 0            0                     The Super Mario Bros. Movie  2023
# 1            1                               Top Gun: Maverick  2022
# 2            2                         Spider-Man: No Way Home  2021
# 3            3                               Bad Boys for Life  2020
# 4            4                               Avengers: Endgame  2019
# 5            5                                   Black Panther  2018
# 6            6         Star Wars: Episode VIII - The Last Jedi  2017
# 7            7                                    Finding Dory  2016
# 8            8                                  Jurassic World  2015
# 9            9                         Guardians of the Galaxy  2014
# 10          10                                      Iron Man 3  2013
# 11          11                                    The Avengers  2012
# 12          12    Harry Potter and the Deathly Hallows: Part 2  2011
# ...

# %%
int_for_df(DomesticYearly, 'total gross')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12432\615951099.py in <module>
# ----> 1 int_for_df(DomesticYearly, 'total gross')
#
# ~\AppData\Local\Temp\ipykernel_12432\1959393045.py in int_for_df(dataframe, col)
#       3     for i in range(0, len(dataframe)):
#       4         c = dataframe[col][i]
# ----> 5         c = c.lstrip('$')
#       6         c = c.replace(',', '')
#       7         c = int(c)
#
# AttributeError: 'int' object has no attribute 'lstrip'

# %%
sns.scatterplot(data=DomesticYearly.head(10), y='#1 movie', x='year').set(title='The 10 latest #1 movies of the year')
# Out:
# [Text(0.5, 1.0, 'The 10 latest #1 movies of the year')]

# %%
sns.barplot(data=DomesticYearly.head(5), y='#1 movie', x='total gross').set(title='The last 5 years of top movies profits', xlabel='Total profit earned that year')
# Out:
# [Text(0.5, 1.0, 'The last 5 years of top movies profits'),
#  Text(0.5, 0, 'Total profit earned that year')]

# %%
sns.barplot(data=DomesticYearly.head(25), y='#1 movie', x='total gross').set(title='The last 25 years of top movies profits', xlabel='Total profit earned that year')
# Out:
# [Text(0.5, 1.0, 'The last 25 years of top movies profits'),
#  Text(0.5, 0, 'Total profit earned that year')]

# %%
sns.barplot(data=DomesticYearly, y='#1 movie', x='total gross').set(title='The last 47 years of top movies profits', xlabel='Total profit earned that year')
# Out:
# [Text(0.5, 1.0, 'The last 47 years of top movies profits'),
#  Text(0.5, 0, 'Total profit earned that year')]
